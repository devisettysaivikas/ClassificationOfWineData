# %% [markdown]
# # Classifying the classes of wine from the wine dataset

# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
#importing the dataset into pandas dataframe 
df = pd.read_csv ("wine.csv")
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06  0.28  2.29       5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.380000  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.680000  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.800000  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.320000  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.750000  1.05
# 5    1  14.39  1.87  2.45  14.6   96  2.50  2.52  0.30  1.98   5.250000  1.02
# 6    1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25   5.050000  1.06
# 7    1  14.83  1.64  2.17  14.0   97  2.80  2.98  0.29  1.98   5.200000  1.08
# 8    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.220000  1.01
# 9    1  14.10  2.16  2.30  18.0  105  2.95  3.32  0.22  2.38   5.750000  1.25
# 10   1  14.12  1.48  2.32  16.8   95  2.20  2.43  0.26  1.57   5.000000  1.17
# ...

# %%
#naming the columns in the data frame
df.columns=['class','Alcohol','Malicacid','Ash','Alcalinityofash','Magnesium','Totalphenols','Flavanoids','Nonflavanoidphenols','Proanthocyanins','Colorintensity','Hue','OD280/OD315','Proline']
df
# Out:
#      class  Alcohol  Malicacid   Ash  Alcalinityofash  Magnesium  \
# 0        1    13.20       1.78  2.14             11.2        100
# 1        1    13.16       2.36  2.67             18.6        101
# 2        1    14.37       1.95  2.50             16.8        113
# 3        1    13.24       2.59  2.87             21.0        118
# 4        1    14.20       1.76  2.45             15.2        112
# 5        1    14.39       1.87  2.45             14.6         96
# 6        1    14.06       2.15  2.61             17.6        121
# 7        1    14.83       1.64  2.17             14.0         97
# 8        1    13.86       1.35  2.27             16.0         98
# 9        1    14.10       2.16  2.30             18.0        105
# 10       1    14.12       1.48  2.32             16.8         95
# 11       1    13.75       1.73  2.41             16.0         89
# 12       1    14.75       1.73  2.39             11.4         91
# ...

# %%
#Finding mean,minimum and maximum values to find the ouliers
df.describe()
# Out:
#             class     Alcohol   Malicacid         Ash  Alcalinityofash  \
# count  177.000000  177.000000  177.000000  177.000000       177.000000
# mean     1.943503   12.993672    2.339887    2.366158        19.516949
# std      0.773991    0.808808    1.119314    0.275080         3.336071
# min      1.000000   11.030000    0.740000    1.360000        10.600000
# 25%      1.000000   12.360000    1.600000    2.210000        17.200000
# 50%      2.000000   13.050000    1.870000    2.360000        19.500000
# 75%      3.000000   13.670000    3.100000    2.560000        21.500000
# max      3.000000   14.830000    5.800000    3.230000        30.000000
#
#         Magnesium  Totalphenols  Flavanoids  Nonflavanoidphenols  \
# count  177.000000    177.000000  177.000000           177.000000
# mean    99.587571      2.292260    2.023446             0.362316
# std     14.174018      0.626465    0.998658             0.124653
# min     70.000000      0.980000    0.340000             0.130000
# ...

# %% [markdown]
# There are no outliers in the data as all the values in the respective columns are close to the mean value of the columns

# %% [markdown]
# # Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# Scaled the dataset using MinMaxScaler

# %% [markdown]
# # Decision tree

# %%
from sklearn import tree
#converting the pandas dataframe to arrays
X = df[df.columns[1:13]]
y = df["class"]
clf = DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
from sklearn.model_selection import train_test_split  
from sklearn.metrics import accuracy_score 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 100)

# %%
y_pred_DecisionTreeClassifier = clf.predict(X_test) 
print ("Desicion Tree Accuracy is ",accuracy_score(y_test, y_pred_DecisionTreeClassifier)*100 )
# Out:
# Desicion Tree Accuracy is  100.0

# %%
y_pred_DecisionTreeClassifier
# Out:
# array([1, 2, 1, 2, 3, 3, 2, 3, 1, 2, 1, 3, 3, 2, 2, 1, 3, 1, 1, 3, 2, 2,
#        3, 1, 3, 3, 2, 3, 3, 3, 1, 2, 2, 3, 3, 3, 2, 2, 3, 1, 2, 3, 2, 2,
#        2], dtype=int64)

# %%
#Using 10 fold cross validation
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf, X, y, cv=10))
Decision_tree_scores=cross_val_score(clf, X, y, cv=10)
# Out:
# [0.94736842 0.83333333 0.88888889 0.72222222 0.88888889 1.
#  0.94444444 0.94444444 1.         1.        ]

# %%
import statistics
statistics.mean(Decision_tree_scores)*100
# Out:
# 90.57383040935673

# %% [markdown]
# Accuracy of the Decision tree while using 10 fold cross validation is 90.57383040935673

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomforest =RandomForestClassifier(n_estimators=10)

# %%
randomforest.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred_DecisionTreeClassifier = randomforest.predict(X_test) 
print ("Random Forest Accuracy is ",accuracy_score(y_test, y_pred_DecisionTreeClassifier)*100 )
# Out:
# Random Forest Accuracy is  100.0

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf, X, y, cv=10))
Random_Forest_scores=cross_val_score(clf, X, y, cv=10)
statistics.mean(Random_Forest_scores)*100
# Out:
# [0.84210526 0.83333333 0.88888889 0.72222222 0.88888889 1.
#  0.94444444 1.         1.         1.        ]
# 91.68494152046783

# %% [markdown]
# Accuracy of the Random Forest using 10 fold cross validation is 91.68494152046783.Accuracy of the Random Forest is higher than Decision tree

# %% [markdown]
# # KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knnclassifier =KNeighborsClassifier(n_neighbors=10)

# %%
knn_classifier_scores=cross_val_score(knnclassifier, X, y, cv=10)
statistics.mean(knn_classifier_scores)
# Out:
# 0.770796783625731

# %%
knnclassifier =KNeighborsClassifier()

# %%
for k in range(1,50):
    knnclassifier =KNeighborsClassifier(n_neighbors=k)
    knn_classifier_scores=cross_val_score(knnclassifier, X, y, cv=10)
    print(statistics.mean(knn_classifier_scores)*100)
# Out:
# 85.97953216374269
# 80.96856725146199
# 87.02119883040935
# 83.19078947368422
# 83.12134502923976
# 79.78801169590643
# 80.31432748538012
# 80.96856725146199
# 78.1907894736842
# 77.0796783625731
# 77.7046783625731
# 77.63523391812865
# 76.52412280701755
# 77.10891812865496
# 77.10891812865496
# 77.66447368421052
# 77.03947368421052
# 75.95760233918128
# 74.1922514619883
# 74.29093567251462
# 74.36038011695906
# 72.06871345029239
# 73.1798245614035
# 73.73538011695906
# 73.1798245614035
# 71.4437134502924
# 71.4437134502924
# 70.33260233918128
# 69.22149122807018
# 69.77704678362574
# 68.04093567251462
# 68.04093567251462
# 65.74926900584795
# 65.72002923976609
# 65.72002923976609
# 65.74926900584795
# 65.74926900584795
# 65.72002923976609
# 65.16447368421052
# 66.34502923976609
# 64.05336257309942
# 62.942251461988306
# 63.49780701754386
# 63.49780701754386
# 64.12280701754386
# 63.49780701754386
# 62.3172514619883
# 62.942251461988306
# 62.942251461988306

# %% [markdown]
# Accuracy of KNN is changing with change in K.Value of K makes a substantial difference in KNN model.Accuracy of the KNN is high when k=3.Accuracy of KNN is 87.02119883040935

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# # MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MultinomialNB_classifier =MultinomialNB()
MultinomialNB_classifier_scores=cross_val_score(MultinomialNB_classifier, X, y, cv=10)
statistics.mean(MultinomialNB_classifier_scores)*100
# Out:
# 86.87134502923976

# %% [markdown]
# Accuracy of MultinomialNB with 10 fold cross validation is 86.87134502923976

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GaussianNB_classifier =GaussianNB()
GaussianNB_classifier_scores=cross_val_score(GaussianNB_classifier, X, y, cv=10)
statistics.mean(GaussianNB_classifier_scores)*100
# Out:
# 94.50292397660819

# %% [markdown]
# Accuracy of GaussianNB with 10 fold cross validation is 94.50292397660819.Accuracy of GaussianNB is higher than MultinomialNB

# %% [markdown]
# Conclusion: All the models are classifying well. Among all the models GaussianNB is having the highest accuracy and multinomial NB is having the lowest accuracy.
